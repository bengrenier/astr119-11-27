# %% [markdown]
# ## Use a simple number generator to simulate a simple Gaussian

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Set some properties of the random system

# %%
n_samples = 10000
n_bins = 100

sigma = 1.0

mu = 0.0

# %%
x = np.random.normal(mu,sigma,n_samples)
print(x.min())
print(x.max())
# Out:
# -4.380920148503539
# 3.7351276085741247

# %% [markdown]
# ## Define a function to plot a Gaussian

# %%
def gaussian(x,mu,sigma):
    return 1./(2.0*np.pi*sigma**2)**0.5 * np.exp(-0.5*((x-mu)/sigma)**2)

# %%
fig = plt.figure(figsize=(7,7))
y_hist, x_hist, ignred =plt.hist(x,bins=n_bins,range=[-5,5],density=True)
xx = np.linspace(-5.0,5.0,1000)
plt.plot(xx,gaussian(xx,mu,sigma),color="red")
plt.ylim([0,0.5])
plt.xlim([-5,5])
plt.gca().set_aspect(20)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
